# %%
from hurricane_app import download_hurricane_data,process_hurricane_data
from hurdat2parser import Hurdat2

# %%
df = process_hurricane_data(download_hurricane_data())

# %%
data_file = "hurdat2-1851-2024-040425.txt"
parser = Hurdat2(data_file)

# %%
parser
# Out:
# <hurdat2parser.Hurdat2 object - North Atlantic Basin: 1851-2024 - at 0x000000011F674C50>

# %%
df[df["year"] == 2024]
# Out:
#        storm_id     name      date  time status  latitude  longitude  \
# 54747  AL011851  UNNAMED  20240617  1800     DB      19.9      -92.7
# 54748  AL011851  UNNAMED  20240618  0000     DB      20.4      -92.7
# 54749  AL011851  UNNAMED  20240618  0600     DB      20.9      -92.7
# 54750  AL011851  UNNAMED  20240618  1200     DB      21.5      -92.6
# 54751  AL011851  UNNAMED  20240618  1800     DB      22.0      -92.6
# ...         ...      ...       ...   ...    ...       ...        ...
# 55225  AL011851  UNNAMED  20241117  0600     TS      16.5      -87.5
# 55226  AL011851  UNNAMED  20241117  1200     TS      16.8      -87.9
# 55227  AL011851  UNNAMED  20241117  1400     TS      17.0      -88.3
# 55228  AL011851  UNNAMED  20241117  1800     TD      17.4      -89.1
# 55229  AL011851  UNNAMED  20241118  0000     TD      17.9      -90.2
#
#        wind_speed  year
# 54747          35  2024
# 54748          35  2024
# 54749          35  2024
# 54750          35  2024
# ...
